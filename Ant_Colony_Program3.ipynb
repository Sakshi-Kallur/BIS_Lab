# %%
import numpy as np
import random


# Define cities and their coordinates
cities = [
    (0, 0),    # City 1
    (1, 3),    # City 2
    (4, 3),    # City 3
    (6, 1),    # City 4
    (3, 2),    # City 5
]


# Function to calculate the Euclidean distance between two cities
def distance(city1, city2):
    return np.sqrt((city1[0] - city2[0])**2 + (city1[1] - city2[1])**2)


# Create a distance matrix
n_cities = len(cities)
dist_matrix = np.zeros((n_cities, n_cities))
for i in range(n_cities):
    for j in range(i+1, n_cities):
        dist_matrix[i][j] = dist_matrix[j][i] = distance(cities[i], cities[j])


# Parameters
n_ants = 10          # Number of ants
n_iterations = 100   # Number of iterations
alpha = 1.0          # Pheromone importance
beta = 2.0           # Distance importance
rho = 0.1            # Pheromone evaporation rate
tau0 = 1.0           # Initial pheromone level


# Initialize pheromone matrix
pheromone = np.full((n_cities, n_cities), tau0)


# Function to choose the next city based on probabilities
def choose_next_city(current_city, visited, pheromone, dist_matrix, alpha, beta):
    unvisited = [city for city in range(n_cities) if city not in visited]
    pheromone_values = [pheromone[current_city][city]**alpha * (1 / dist_matrix[current_city][city])**beta for city in unvisited]

    total = sum(pheromone_values)
    probabilities = [value / total for value in pheromone_values]

    return random.choices(unvisited, probabilities)[0]


# Update pheromones function
def update_pheromones(pheromone, all_solutions, dist_matrix, rho):
    pheromone *= (1 - rho)  # Evaporate pheromone
    for solution in all_solutions:
        # Calculate total tour length
        tour_length = sum(dist_matrix[solution[i]][solution[i+1]] for i in range(len(solution)-1))
        tour_length += dist_matrix[solution[-1]][solution[0]]  # Return to the starting city

        # Deposit pheromone inversely proportional to the tour length
        for i in range(len(solution)-1):
            pheromone[solution[i]][solution[i+1]] += 1.0 / tour_length
        pheromone[solution[-1]][solution[0]] += 1.0 / tour_length  # Return to the starting city


# Main ACO loop
best_tour = None
best_tour_length = float('inf')


for iteration in range(n_iterations):
    all_solutions = []

    # Step 3: Ants construct solutions
    for _ in range(n_ants):
        solution = []
        visited = set()
        current_city = random.randint(0, n_cities-1)
        visited.add(current_city)
        solution.append(current_city)

        while len(visited) < n_cities:
            next_city = choose_next_city(current_city, visited, pheromone, dist_matrix, alpha, beta)
            visited.add(next_city)
            solution.append(next_city)
            current_city = next_city

        all_solutions.append(solution)

        # Step 4: Evaluate the current solution and update the best solution
        tour_length = sum(dist_matrix[solution[i]][solution[i+1]] for i in range(len(solution)-1))
        tour_length += dist_matrix[solution[-1]][solution[0]]  # Return to the starting city

        if tour_length < best_tour_length:
            best_tour_length = tour_length
            best_tour = solution

    # Update pheromones
    update_pheromones(pheromone, all_solutions, dist_matrix, rho)


    print(f"Iteration {iteration+1}, Best tour length: {best_tour_length}")
# Final best solution
print("\nBest Tour:", best_tour)
print("Best Tour Length:", best_tour_length)
# Print the path with city coordinates
print("\nPath with City Coordinates:")
for city_index in best_tour:
 print(f"City {city_index + 1}: {cities[city_index]}")
# Out:
# Iteration 1, Best tour length: 15.758533720546938
# Iteration 2, Best tour length: 15.723748855085672
# Iteration 3, Best tour length: 15.723748855085672
# Iteration 4, Best tour length: 15.723748855085672
# Iteration 5, Best tour length: 15.723748855085672
# Iteration 6, Best tour length: 15.723748855085672
# Iteration 7, Best tour length: 15.723748855085672
# Iteration 8, Best tour length: 15.723748855085672
# Iteration 9, Best tour length: 15.723748855085672
# Iteration 10, Best tour length: 15.723748855085672
# Iteration 11, Best tour length: 15.723748855085672
# Iteration 12, Best tour length: 15.723748855085672
# Iteration 13, Best tour length: 15.723748855085672
# Iteration 14, Best tour length: 15.723748855085672
# Iteration 15, Best tour length: 15.723748855085672
# Iteration 16, Best tour length: 15.723748855085672
# Iteration 17, Best tour length: 15.723748855085672
# Iteration 18, Best tour length: 15.723748855085672
# Iteration 19, Best tour length: 15.723748855085672
# Iteration 20, Best tour length: 15.723748855085672
# Iteration 21, Best tour length: 15.723748855085672
# Iteration 22, Best tour length: 15.723748855085672
# Iteration 23, Best tour length: 15.723748855085672
# Iteration 24, Best tour length: 15.723748855085672
# Iteration 25, Best tour length: 15.723748855085672
# Iteration 26, Best tour length: 15.723748855085672
# Iteration 27, Best tour length: 15.723748855085672
# Iteration 28, Best tour length: 15.723748855085672
# Iteration 29, Best tour length: 15.723748855085672
# Iteration 30, Best tour length: 15.723748855085672
# Iteration 31, Best tour length: 15.723748855085672
# Iteration 32, Best tour length: 15.723748855085672
# Iteration 33, Best tour length: 15.723748855085672
# Iteration 34, Best tour length: 15.723748855085672
# Iteration 35, Best tour length: 15.723748855085672
# Iteration 36, Best tour length: 15.723748855085672
# Iteration 37, Best tour length: 15.723748855085672
# Iteration 38, Best tour length: 15.723748855085672
# Iteration 39, Best tour length: 15.723748855085672
# Iteration 40, Best tour length: 15.723748855085672
# Iteration 41, Best tour length: 15.723748855085672
# Iteration 42, Best tour length: 15.723748855085672
# Iteration 43, Best tour length: 15.723748855085672
# Iteration 44, Best tour length: 15.723748855085672
# Iteration 45, Best tour length: 15.723748855085672
# Iteration 46, Best tour length: 15.723748855085672
# Iteration 47, Best tour length: 15.723748855085672
# Iteration 48, Best tour length: 15.723748855085672
# Iteration 49, Best tour length: 15.723748855085672
# Iteration 50, Best tour length: 15.723748855085672
# Iteration 51, Best tour length: 15.723748855085672
# Iteration 52, Best tour length: 15.723748855085672
# Iteration 53, Best tour length: 15.723748855085672
# Iteration 54, Best tour length: 15.723748855085672
# Iteration 55, Best tour length: 15.723748855085672
# Iteration 56, Best tour length: 15.723748855085672
# Iteration 57, Best tour length: 15.723748855085672
# Iteration 58, Best tour length: 15.723748855085672
# Iteration 59, Best tour length: 15.723748855085672
# Iteration 60, Best tour length: 15.723748855085672
# Iteration 61, Best tour length: 15.723748855085672
# Iteration 62, Best tour length: 15.723748855085672
# Iteration 63, Best tour length: 15.723748855085672
# Iteration 64, Best tour length: 15.723748855085672
# Iteration 65, Best tour length: 15.723748855085672
# Iteration 66, Best tour length: 15.723748855085672
# Iteration 67, Best tour length: 15.723748855085672
# Iteration 68, Best tour length: 15.723748855085672
# Iteration 69, Best tour length: 15.723748855085672
# Iteration 70, Best tour length: 15.723748855085672
# Iteration 71, Best tour length: 15.723748855085672
# Iteration 72, Best tour length: 15.723748855085672
# Iteration 73, Best tour length: 15.723748855085672
# Iteration 74, Best tour length: 15.723748855085672
# Iteration 75, Best tour length: 15.723748855085672
# Iteration 76, Best tour length: 15.723748855085672
# Iteration 77, Best tour length: 15.723748855085672
# Iteration 78, Best tour length: 15.723748855085672
# Iteration 79, Best tour length: 15.723748855085672
# Iteration 80, Best tour length: 15.723748855085672
# Iteration 81, Best tour length: 15.723748855085672
# Iteration 82, Best tour length: 15.723748855085672
# Iteration 83, Best tour length: 15.723748855085672
# Iteration 84, Best tour length: 15.723748855085672
# Iteration 85, Best tour length: 15.723748855085672
# Iteration 86, Best tour length: 15.723748855085672
# Iteration 87, Best tour length: 15.723748855085672
# Iteration 88, Best tour length: 15.723748855085672
# Iteration 89, Best tour length: 15.723748855085672
# Iteration 90, Best tour length: 15.723748855085672
# Iteration 91, Best tour length: 15.723748855085672
# Iteration 92, Best tour length: 15.723748855085672
# Iteration 93, Best tour length: 15.723748855085672
# Iteration 94, Best tour length: 15.723748855085672
# Iteration 95, Best tour length: 15.723748855085672
# Iteration 96, Best tour length: 15.723748855085672
# Iteration 97, Best tour length: 15.723748855085672
# Iteration 98, Best tour length: 15.723748855085672
# Iteration 99, Best tour length: 15.723748855085672
# Iteration 100, Best tour length: 15.723748855085672
#
# Best Tour: [2, 4, 1, 0, 3]
# Best Tour Length: 15.723748855085672
#
# Path with City Coordinates:
# City 3: (4, 3)
# City 5: (3, 2)
# City 2: (1, 3)
# City 1: (0, 0)
# City 4: (6, 1)
